# %% [markdown]
# <a href="https://colab.research.google.com/github/ignat24/Python/blob/master/Laba1_Sifar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
 
numpy.random.seed(42)
 
img_rows, img_cols = 32, 32
 
(X_train,y_train), (X_test, y_test)=mnist.load_data()
 
X_train=X_train.reshape(X_train.shape[0], img_rows, img_cols,1)
X_test=X_test.reshape(X_test.shape[0], img_rows, img_cols,1)
input_shape=(img_rows, img_cols,1)
 
X_train=X_train.astype('float32')
X_test=X_test.astype('float32')
 
X_train/=255
X_test/=255
 
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)
 
model=Sequential()
 
model.add(Conv2D(75,kernel_size=(5,5),
                activation='relu',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size(2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(100,(5,5),activation='relu'))
model.add(MaxPooling2D(pool_size(2,2)))
model.add(Dropout(0.2))
model.add(Flatten())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c607d80a09f2> in <module>()
#      30                 activation='relu',
#      31                 input_shape=input_shape))
# ---> 32 model.add(MaxPooling2D(pool_size(2, 2)))
#      33 model.add(Dropout(0.2))
#      34 model.add(Conv2D(100,(5,5),activation='relu'))
#
# NameError: name 'pool_size' is not defined

# %%
import numpy
from tensorflow import keras

# from keras.datasets import mnist
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.constraints import maxnorm
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import accuracy_score

# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Размер изображения
img_rows, img_cols = 32, 32

# Загружаем данные
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 3)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 3)
input_shape = (img_rows, img_cols, 3)


# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = np_utils.to_categorical(y_train)
Y_test = np_utils.to_categorical(y_test)

MODELS_COUNT=5

y_pred=None
for i in range(MODELS_COUNT):
  print("Model #",i)


  # Создаем последовательную модель
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3),
                  activation='relu',
                  input_shape=(32,32,3),padding = "same"))
  model.add(Conv2D(64, kernel_size=(4, 4),
                  activation='relu',
                   padding = "same"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(64, (3, 3), activation='relu',padding = "same"))
  model.add(Conv2D(128, (3, 3), activation='relu'))
  model.add(Dropout(0.2)) 
  model.add(Flatten())
  model.add(Dense(500, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(10, activation='softmax'))

  # model = Sequential()

  # model.add(Conv2D(32, (3, 3), padding='same',
  #                       input_shape=(32, 32, 3), activation='relu'))
  # model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
  # model.add(MaxPooling2D(pool_size=(2, 2)))
  # model.add(Dropout(0.25))
  # model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
  # model.add(Conv2D(64, (3, 3), activation='relu'))
  # model.add(MaxPooling2D(pool_size=(2, 2)))
  # model.add(Dropout(0.25))
  # model.add(Flatten())
  # model.add(Dense(500, activation='relu'))
  # model.add(Dropout(0.5))
  # model.add(Dense(10, activation='softmax'))


  # model.add(Conv2D(64, kernel_size=(3, 3),
  #                 input_shape=input_shape,
  #                  activation='relu'))
  # model.add(MaxPooling2D(pool_size=(2, 2)))
  # model.add(Dropout(0.2))

  # model.add(Conv2D(64,(4, 4),
  #           activation='relu'))
  # model.add(MaxPooling2D(pool_size=(2, 2)))
  

  # model.add(Conv2D(128,(5, 5), activation='relu'))
  # model.add(MaxPooling2D(pool_size=(2, 2)))
  # model.add(Dropout(0.2))

  # # model.add(Conv2D(512, (3, 3), padding='same',
  # #           activation='relu'))
  # # model.add(MaxPooling2D(pool_size=(2, 2)))
  # # model.add(Dropout(0.2))

  # model.add(Flatten())
  # model.add(Dense(512,activation='relu'))
  # model.add(Dropout(0.3))
  # model.add(Dense(10,activation='softmax'))

  model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
  # print(model.summary())

  # checkpoint_filepath = 'model_' + str(i) + '.h5'
  # model_checkpoint_callback = ModelCheckpoint(
  #     filepath=checkpoint_filepath,
  #     save_weights_only=True,
  #     montior='val_accuracy',
  #     mode='max',
  #     save_best_only=True)
  
  model.fit(X_train,Y_train,batch_size=128, epochs=25, validation_split=0.1, verbose=2)

  # model.load_weights(checkpoint_filepath)

  scores=model.evaluate(X_test, Y_test, verbose=0)
  print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

  if y_pred is None:
    y_pred = model.predict(X_test)
  else:
    y_pred +=model.predict(X_test)

y_pred /= MODELS_COUNT
pred = numpy.argmax(y_pred, axis=1)
acc_test = accuracy_score(y_test,pred)
# print("acc_test: ()".format(acc_test))
print("Final accuracy: {}%".format(round(acc_test*100,2)))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# Model # 0
# Epoch 1/25
# 352/352 - 41s - loss: 1.6096 - accuracy: 0.4144 - val_loss: 1.1715 - val_accuracy: 0.5808
# Epoch 2/25
# 352/352 - 7s - loss: 1.1272 - accuracy: 0.5998 - val_loss: 0.9165 - val_accuracy: 0.6774
# Epoch 3/25
# 352/352 - 7s - loss: 0.9135 - accuracy: 0.6797 - val_loss: 0.7890 - val_accuracy: 0.7278
# Epoch 4/25
# 352/352 - 7s - loss: 0.7849 - accuracy: 0.7257 - val_loss: 0.7730 - val_accuracy: 0.7384
# Epoch 5/25
# 352/352 - 8s - loss: 0.6804 - accuracy: 0.7603 - val_loss: 0.6818 - val_accuracy: 0.7602
# Epoch 6/25
# 352/352 - 8s - loss: 0.5946 - accuracy: 0.7905 - val_loss: 0.6826 - val_accuracy: 0.7638
# Epoch 7/25
# 352/352 - 8s - loss: 0.5132 - accuracy: 0.8171 - val_loss: 0.6662 - val_accuracy: 0.7702
# Epoch 8/25
# 352/352 - 8s - loss: 0.4460 - accuracy: 0.8416 - val_loss: 0.6808 - val_accuracy: 0.7838
# Epoch 9/25
# 352/352 - 8s - loss: 0.3915 - accuracy: 0.8612 - val_loss: 0.6975 - val_accuracy: 0.7780
# Epoch 10/25
# 352/352 - 8s - loss: 0.3463 - accuracy: 0.8771 - val_loss: 0.7705 - val_accuracy: 0.7776
# Epoch 11/25
# 352/352 - 8s - loss: 0.3082 - accuracy: 0.8906 - val_loss: 0.7409 - val_accuracy: 0.7812
# Epoch 12/25
# 352/352 - 8s - loss: 0.2633 - accuracy: 0.9076 - val_loss: 0.8297 - val_accuracy: 0.7728
# Epoch 13/25
# 352/352 - 8s - loss: 0.2553 - accuracy: 0.9092 - val_loss: 0.8426 - val_accuracy: 0.7824
# Epoch 14/25
# 352/352 - 8s - loss: 0.2299 - accuracy: 0.9189 - val_loss: 0.8429 - val_accuracy: 0.7816
# Epoch 15/25
# 352/352 - 8s - loss: 0.2030 - accuracy: 0.9281 - val_loss: 0.9127 - val_accuracy: 0.7792
# Epoch 16/25
# 352/352 - 8s - loss: 0.1906 - accuracy: 0.9339 - val_loss: 0.8544 - val_accuracy: 0.7826
# Epoch 17/25
# 352/352 - 8s - loss: 0.1794 - accuracy: 0.9367 - val_loss: 0.9923 - val_accuracy: 0.7726
# Epoch 18/25
# 352/352 - 8s - loss: 0.1743 - accuracy: 0.9405 - val_loss: 0.9224 - val_accuracy: 0.7800
# Epoch 19/25
# 352/352 - 8s - loss: 0.1651 - accuracy: 0.9428 - val_loss: 0.9855 - val_accuracy: 0.7754
# Epoch 20/25
# 352/352 - 8s - loss: 0.1594 - accuracy: 0.9426 - val_loss: 1.0217 - val_accuracy: 0.7812
# Epoch 21/25
# 352/352 - 8s - loss: 0.1521 - accuracy: 0.9474 - val_loss: 0.9763 - val_accuracy: 0.7832
# Epoch 22/25
# 352/352 - 8s - loss: 0.1427 - accuracy: 0.9499 - val_loss: 0.9999 - val_accuracy: 0.7876
# Epoch 23/25
# 352/352 - 8s - loss: 0.1434 - accuracy: 0.9497 - val_loss: 1.0295 - val_accuracy: 0.7856
# Epoch 24/25
# 352/352 - 8s - loss: 0.1422 - accuracy: 0.9506 - val_loss: 0.9907 - val_accuracy: 0.7844
# Epoch 25/25
# 352/352 - 8s - loss: 0.1295 - accuracy: 0.9562 - val_loss: 1.0410 - val_accuracy: 0.7834
# Точность работы на тестовых данных: 77.30%
# Model # 1
# Epoch 1/25
# 352/352 - 9s - loss: 1.5690 - accuracy: 0.4275 - val_loss: 1.1738 - val_accuracy: 0.5748
# Epoch 2/25
# 352/352 - 8s - loss: 1.1350 - accuracy: 0.5944 - val_loss: 0.9218 - val_accuracy: 0.6758
# Epoch 3/25
# 352/352 - 8s - loss: 0.9368 - accuracy: 0.6718 - val_loss: 0.8084 - val_accuracy: 0.7186
# Epoch 4/25
# 352/352 - 8s - loss: 0.8093 - accuracy: 0.7168 - val_loss: 0.7543 - val_accuracy: 0.7372
# Epoch 5/25
# 352/352 - 8s - loss: 0.6972 - accuracy: 0.7544 - val_loss: 0.7124 - val_accuracy: 0.7572
# Epoch 6/25
# 352/352 - 8s - loss: 0.6103 - accuracy: 0.7869 - val_loss: 0.6722 - val_accuracy: 0.7650
# Epoch 7/25
# 352/352 - 8s - loss: 0.5461 - accuracy: 0.8061 - val_loss: 0.6762 - val_accuracy: 0.7698
# Epoch 8/25
# 352/352 - 8s - loss: 0.4775 - accuracy: 0.8314 - val_loss: 0.7375 - val_accuracy: 0.7662
# Epoch 9/25
# 352/352 - 8s - loss: 0.4282 - accuracy: 0.8495 - val_loss: 0.6639 - val_accuracy: 0.7798
# Epoch 10/25
# 352/352 - 8s - loss: 0.3767 - accuracy: 0.8673 - val_loss: 0.7093 - val_accuracy: 0.7778
# Epoch 11/25
# 352/352 - 8s - loss: 0.3314 - accuracy: 0.8845 - val_loss: 0.7408 - val_accuracy: 0.7842
# Epoch 12/25
# 352/352 - 8s - loss: 0.2926 - accuracy: 0.8955 - val_loss: 0.7632 - val_accuracy: 0.7858
# Epoch 13/25
# 352/352 - 8s - loss: 0.2725 - accuracy: 0.9033 - val_loss: 0.7901 - val_accuracy: 0.7722
# Epoch 14/25
# 352/352 - 8s - loss: 0.2461 - accuracy: 0.9138 - val_loss: 0.8287 - val_accuracy: 0.7750
# Epoch 15/25
# 352/352 - 8s - loss: 0.2259 - accuracy: 0.9184 - val_loss: 0.7909 - val_accuracy: 0.7848
# Epoch 16/25
# 352/352 - 8s - loss: 0.2175 - accuracy: 0.9233 - val_loss: 0.8548 - val_accuracy: 0.7760
# Epoch 17/25
# 352/352 - 8s - loss: 0.2015 - accuracy: 0.9284 - val_loss: 0.8819 - val_accuracy: 0.7850
# Epoch 18/25
# 352/352 - 8s - loss: 0.1916 - accuracy: 0.9316 - val_loss: 0.8585 - val_accuracy: 0.7860
# Epoch 19/25
# 352/352 - 8s - loss: 0.1691 - accuracy: 0.9408 - val_loss: 0.8968 - val_accuracy: 0.7858
# Epoch 20/25
# 352/352 - 8s - loss: 0.1696 - accuracy: 0.9413 - val_loss: 0.8920 - val_accuracy: 0.7818
# Epoch 21/25
# 352/352 - 8s - loss: 0.1604 - accuracy: 0.9453 - val_loss: 0.9129 - val_accuracy: 0.7814
# Epoch 22/25
# 352/352 - 8s - loss: 0.1551 - accuracy: 0.9469 - val_loss: 0.9269 - val_accuracy: 0.7872
# Epoch 23/25
# 352/352 - 8s - loss: 0.1539 - accuracy: 0.9462 - val_loss: 0.9485 - val_accuracy: 0.7840
# Epoch 24/25
# 352/352 - 8s - loss: 0.1479 - accuracy: 0.9490 - val_loss: 0.9667 - val_accuracy: 0.7868
# Epoch 25/25
# 352/352 - 8s - loss: 0.1473 - accuracy: 0.9488 - val_loss: 1.0448 - val_accuracy: 0.7848
# Точность работы на тестовых данных: 76.91%
# Model # 2
# Epoch 1/25
# 352/352 - 9s - loss: 1.5939 - accuracy: 0.4191 - val_loss: 1.1934 - val_accuracy: 0.5792
# Epoch 2/25
# 352/352 - 8s - loss: 1.1433 - accuracy: 0.5914 - val_loss: 0.9306 - val_accuracy: 0.6810
# Epoch 3/25
# 352/352 - 8s - loss: 0.9228 - accuracy: 0.6750 - val_loss: 0.7814 - val_accuracy: 0.7226
# Epoch 4/25
# 352/352 - 8s - loss: 0.7818 - accuracy: 0.7231 - val_loss: 0.7050 - val_accuracy: 0.7536
# Epoch 5/25
# 352/352 - 8s - loss: 0.6793 - accuracy: 0.7620 - val_loss: 0.6878 - val_accuracy: 0.7574
# Epoch 6/25
# 352/352 - 8s - loss: 0.5891 - accuracy: 0.7921 - val_loss: 0.6995 - val_accuracy: 0.7608
# Epoch 7/25
# 352/352 - 8s - loss: 0.5017 - accuracy: 0.8227 - val_loss: 0.6436 - val_accuracy: 0.7808
# Epoch 8/25
# 352/352 - 8s - loss: 0.4383 - accuracy: 0.8453 - val_loss: 0.6721 - val_accuracy: 0.7810
# Epoch 9/25
# 352/352 - 8s - loss: 0.3653 - accuracy: 0.8692 - val_loss: 0.6875 - val_accuracy: 0.7856
# Epoch 10/25
# 352/352 - 8s - loss: 0.3273 - accuracy: 0.8832 - val_loss: 0.7094 - val_accuracy: 0.7822
# Epoch 11/25
# 352/352 - 8s - loss: 0.2906 - accuracy: 0.8951 - val_loss: 0.7437 - val_accuracy: 0.7862
# Epoch 12/25
# 352/352 - 8s - loss: 0.2495 - accuracy: 0.9113 - val_loss: 0.7783 - val_accuracy: 0.7912
# Epoch 13/25
# 352/352 - 8s - loss: 0.2281 - accuracy: 0.9186 - val_loss: 0.8031 - val_accuracy: 0.7872
# Epoch 14/25
# 352/352 - 8s - loss: 0.2091 - accuracy: 0.9257 - val_loss: 0.7921 - val_accuracy: 0.7938
# Epoch 15/25
# 352/352 - 8s - loss: 0.2001 - accuracy: 0.9282 - val_loss: 0.9818 - val_accuracy: 0.7606
# Epoch 16/25
# 352/352 - 8s - loss: 0.1819 - accuracy: 0.9382 - val_loss: 0.8220 - val_accuracy: 0.7878
# Epoch 17/25
# 352/352 - 8s - loss: 0.1757 - accuracy: 0.9387 - val_loss: 0.8386 - val_accuracy: 0.7794
# Epoch 18/25
# 352/352 - 8s - loss: 0.1593 - accuracy: 0.9441 - val_loss: 0.9205 - val_accuracy: 0.7836
# Epoch 19/25
# 352/352 - 8s - loss: 0.1567 - accuracy: 0.9462 - val_loss: 0.9822 - val_accuracy: 0.7758
# Epoch 20/25
# 352/352 - 8s - loss: 0.1495 - accuracy: 0.9480 - val_loss: 0.9828 - val_accuracy: 0.7870
# Epoch 21/25
# 352/352 - 8s - loss: 0.1500 - accuracy: 0.9475 - val_loss: 0.9277 - val_accuracy: 0.7852
# Epoch 22/25
# 352/352 - 8s - loss: 0.1394 - accuracy: 0.9520 - val_loss: 0.9975 - val_accuracy: 0.7784
# Epoch 23/25
# 352/352 - 8s - loss: 0.1353 - accuracy: 0.9539 - val_loss: 0.9865 - val_accuracy: 0.7884
# Epoch 24/25
# 352/352 - 8s - loss: 0.1235 - accuracy: 0.9565 - val_loss: 1.0077 - val_accuracy: 0.7832
# Epoch 25/25
# 352/352 - 8s - loss: 0.1226 - accuracy: 0.9577 - val_loss: 1.0373 - val_accuracy: 0.7852
# Точность работы на тестовых данных: 77.58%
# Model # 3
# Epoch 1/25
# 352/352 - 9s - loss: 1.5560 - accuracy: 0.4353 - val_loss: 1.2391 - val_accuracy: 0.5532
# Epoch 2/25
# 352/352 - 8s - loss: 1.1350 - accuracy: 0.5969 - val_loss: 0.9364 - val_accuracy: 0.6698
# Epoch 3/25
# 352/352 - 8s - loss: 0.9437 - accuracy: 0.6694 - val_loss: 0.8122 - val_accuracy: 0.7124
# Epoch 4/25
# 352/352 - 8s - loss: 0.8046 - accuracy: 0.7157 - val_loss: 0.7556 - val_accuracy: 0.7352
# Epoch 5/25
# 352/352 - 8s - loss: 0.6995 - accuracy: 0.7540 - val_loss: 0.7287 - val_accuracy: 0.7478
# Epoch 6/25
# 352/352 - 8s - loss: 0.6140 - accuracy: 0.7832 - val_loss: 0.6853 - val_accuracy: 0.7628
# Epoch 7/25
# 352/352 - 8s - loss: 0.5332 - accuracy: 0.8095 - val_loss: 0.6951 - val_accuracy: 0.7712
# Epoch 8/25
# 352/352 - 8s - loss: 0.4649 - accuracy: 0.8366 - val_loss: 0.6941 - val_accuracy: 0.7734
# Epoch 9/25
# 352/352 - 8s - loss: 0.4066 - accuracy: 0.8555 - val_loss: 0.6912 - val_accuracy: 0.7760
# Epoch 10/25
# 352/352 - 8s - loss: 0.3498 - accuracy: 0.8759 - val_loss: 0.7510 - val_accuracy: 0.7788
# Epoch 11/25
# 352/352 - 8s - loss: 0.3108 - accuracy: 0.8897 - val_loss: 0.8193 - val_accuracy: 0.7748
# Epoch 12/25
# 352/352 - 8s - loss: 0.2886 - accuracy: 0.8981 - val_loss: 0.7628 - val_accuracy: 0.7864
# Epoch 13/25
# 352/352 - 8s - loss: 0.2545 - accuracy: 0.9108 - val_loss: 0.7805 - val_accuracy: 0.7826
# Epoch 14/25
# 352/352 - 8s - loss: 0.2297 - accuracy: 0.9185 - val_loss: 0.8832 - val_accuracy: 0.7750
# Epoch 15/25
# 352/352 - 8s - loss: 0.2097 - accuracy: 0.9264 - val_loss: 0.8490 - val_accuracy: 0.7856
# Epoch 16/25
# 352/352 - 8s - loss: 0.2002 - accuracy: 0.9294 - val_loss: 0.8836 - val_accuracy: 0.7790
# Epoch 17/25
# 352/352 - 8s - loss: 0.1849 - accuracy: 0.9343 - val_loss: 0.9526 - val_accuracy: 0.7802
# Epoch 18/25
# 352/352 - 8s - loss: 0.1815 - accuracy: 0.9364 - val_loss: 0.9549 - val_accuracy: 0.7734
# Epoch 19/25
# 352/352 - 8s - loss: 0.1723 - accuracy: 0.9399 - val_loss: 0.9565 - val_accuracy: 0.7830
# Epoch 20/25
# 352/352 - 8s - loss: 0.1617 - accuracy: 0.9441 - val_loss: 0.8731 - val_accuracy: 0.7764
# Epoch 21/25
# 352/352 - 8s - loss: 0.1537 - accuracy: 0.9457 - val_loss: 1.0065 - val_accuracy: 0.7788
# Epoch 22/25
# 352/352 - 8s - loss: 0.1391 - accuracy: 0.9514 - val_loss: 0.9796 - val_accuracy: 0.7848
# Epoch 23/25
# 352/352 - 8s - loss: 0.1498 - accuracy: 0.9471 - val_loss: 1.0303 - val_accuracy: 0.7796
# Epoch 24/25
# 352/352 - 8s - loss: 0.1444 - accuracy: 0.9501 - val_loss: 0.9295 - val_accuracy: 0.7872
# Epoch 25/25
# 352/352 - 8s - loss: 0.1360 - accuracy: 0.9529 - val_loss: 0.9853 - val_accuracy: 0.7892
# Точность работы на тестовых данных: 77.36%
# Model # 4
# Epoch 1/25
# 352/352 - 9s - loss: 1.6342 - accuracy: 0.4015 - val_loss: 1.2561 - val_accuracy: 0.5546
# Epoch 2/25
# 352/352 - 8s - loss: 1.2010 - accuracy: 0.5696 - val_loss: 1.0263 - val_accuracy: 0.6432
# Epoch 3/25
# 352/352 - 8s - loss: 0.9923 - accuracy: 0.6486 - val_loss: 0.8363 - val_accuracy: 0.7030
# Epoch 4/25
# 352/352 - 8s - loss: 0.8550 - accuracy: 0.6999 - val_loss: 0.7918 - val_accuracy: 0.7190
# Epoch 5/25
# 352/352 - 8s - loss: 0.7646 - accuracy: 0.7320 - val_loss: 0.7481 - val_accuracy: 0.7398
# Epoch 6/25
# 352/352 - 8s - loss: 0.6787 - accuracy: 0.7620 - val_loss: 0.6920 - val_accuracy: 0.7580
# Epoch 7/25
# 352/352 - 8s - loss: 0.6058 - accuracy: 0.7847 - val_loss: 0.6647 - val_accuracy: 0.7708
# Epoch 8/25
# 352/352 - 8s - loss: 0.5497 - accuracy: 0.8072 - val_loss: 0.6743 - val_accuracy: 0.7698
# Epoch 9/25
# 352/352 - 8s - loss: 0.4904 - accuracy: 0.8276 - val_loss: 0.6807 - val_accuracy: 0.7786
# Epoch 10/25
# 352/352 - 8s - loss: 0.4357 - accuracy: 0.8452 - val_loss: 0.6939 - val_accuracy: 0.7720
# Epoch 11/25
# 352/352 - 8s - loss: 0.3936 - accuracy: 0.8601 - val_loss: 0.7417 - val_accuracy: 0.7750
# Epoch 12/25
# 352/352 - 8s - loss: 0.3533 - accuracy: 0.8754 - val_loss: 0.7580 - val_accuracy: 0.7776
# Epoch 13/25
# 352/352 - 8s - loss: 0.3212 - accuracy: 0.8851 - val_loss: 0.7869 - val_accuracy: 0.7816
# Epoch 14/25
# 352/352 - 8s - loss: 0.2894 - accuracy: 0.8977 - val_loss: 0.8151 - val_accuracy: 0.7732
# Epoch 15/25
# 352/352 - 8s - loss: 0.2702 - accuracy: 0.9035 - val_loss: 0.8114 - val_accuracy: 0.7754
# Epoch 16/25
# 352/352 - 8s - loss: 0.2509 - accuracy: 0.9104 - val_loss: 0.8921 - val_accuracy: 0.7692
# Epoch 17/25
# 352/352 - 8s - loss: 0.2318 - accuracy: 0.9185 - val_loss: 0.8981 - val_accuracy: 0.7744
# Epoch 18/25
# 352/352 - 8s - loss: 0.2283 - accuracy: 0.9200 - val_loss: 0.8931 - val_accuracy: 0.7800
# Epoch 19/25
# 352/352 - 8s - loss: 0.2019 - accuracy: 0.9286 - val_loss: 0.9214 - val_accuracy: 0.7754
# Epoch 20/25
# 352/352 - 8s - loss: 0.1963 - accuracy: 0.9321 - val_loss: 0.8888 - val_accuracy: 0.7782
# Epoch 21/25
# 352/352 - 8s - loss: 0.1890 - accuracy: 0.9339 - val_loss: 0.9474 - val_accuracy: 0.7746
# Epoch 22/25
# 352/352 - 8s - loss: 0.1807 - accuracy: 0.9375 - val_loss: 0.9557 - val_accuracy: 0.7830
# Epoch 23/25
# 352/352 - 8s - loss: 0.1734 - accuracy: 0.9394 - val_loss: 0.9181 - val_accuracy: 0.7832
# Epoch 24/25
# 352/352 - 8s - loss: 0.1649 - accuracy: 0.9438 - val_loss: 1.0138 - val_accuracy: 0.7764
# Epoch 25/25
# 352/352 - 8s - loss: 0.1595 - accuracy: 0.9443 - val_loss: 0.9838 - val_accuracy: 0.7844
# Точность работы на тестовых данных: 77.71%
# Final accuracy: 81.09%
