# %% [markdown]
# <a href="https://colab.research.google.com/github/ignat24/Python/blob/master/Augmentation_Ignatushkin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import math
from tensorflow import keras

# from keras.datasets import mnist
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.constraints import maxnorm
from keras.utils import np_utils,Sequence
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import albumentations as A

# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Размер изображения
img_rows, img_cols = 32, 32

# Загружаем данные
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 3)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 3)
input_shape = (img_rows, img_cols, 3)


# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = np_utils.to_categorical(y_train,10)
Y_test = np_utils.to_categorical(y_test,10)

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.20, random_state=42)

AUGM = A.Compose([    
    A.HorizontalFlip(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.15, scale_limit=0.2, rotate_limit=30, p=0.5),
    A.RandomBrightnessContrast(p=0.5),
])

class DataGenerator(Sequence):
 
    def __init__(self, X_data , y_data, batch_size, for_train, augm, shuffle = True):
        self.X_data = X_data
        self.y_data = y_data 
        self.batch_size = batch_size
        self.for_train = for_train
        self.augm = augm
        self.shuffle = shuffle
        self.n = 0
        self.list_IDs = numpy.arange(len(self.X_data))
        self.on_epoch_end()
        
    def __next__(self):
        # Get one batch of data
        data = self.__getitem__(self.n)
        # Batch index
        self.n += 1
        # If we have processed the entire dataset then
        if self.n >= self.__len__():
            self.on_epoch_end()
            self.n = 0        
        return data

    def __len__(self):
        # Return the number of batches of the dataset
        return math.ceil(len(self.indexes)/self.batch_size)
    
    def __getitem__(self, index):
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size : (index+1)*self.batch_size]        
        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        X = self._generate_x(list_IDs_temp)
        
        if self.for_train:
            y = self._generate_y(list_IDs_temp)
            return X, y
        else:
            return X
        
    def on_epoch_end(self):
        self.indexes = numpy.arange(len(self.X_data))
        if self.shuffle: 
            numpy.random.shuffle(self.indexes)    
            
    def _generate_x(self, list_IDs_temp):
        X = numpy.zeros((self.batch_size, 32, 32, 3), dtype=numpy.float32)
        for i, ID in enumerate(list_IDs_temp):
            X[i] = self.X_data[ID]
            if self.augm:                
                img_augm = AUGM(image=X[i])
                X[i] = img_augm["image"]                
        return X
    
    def _generate_y(self, list_IDs_temp):
        #y = np.empty(self.batch_size)        
        y = numpy.zeros((self.batch_size, 10), dtype=numpy.float32)
        for i, ID in enumerate(list_IDs_temp):            
            y[i] = self.y_data[ID]            
        return y

MODELS_COUNT=5

y_pred=None
for i in range(MODELS_COUNT):
  print("Model #",i)


  # Создаем последовательную модель
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3),
                  activation='relu',
                  input_shape=(32,32,3),padding = "same"))
  model.add(Conv2D(64, kernel_size=(4, 4),
                  activation='relu',
                   padding = "same"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(64, (3, 3), activation='relu',padding = "same"))
  model.add(Conv2D(128, (3, 3), activation='relu'))
  model.add(Dropout(0.2)) 
  model.add(Flatten())
  model.add(Dense(500, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(10, activation='softmax'))

  model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
  # print(model.summary())

  # checkpoint_filepath = 'model_' + str(i) + '.h5'
  # model_checkpoint_callback = ModelCheckpoint(
  #     filepath=checkpoint_filepath,
  #     save_weights_only=True,
  #     montior='val_accuracy',
  #     mode='max',
  #     save_best_only=True)
  train_generator = DataGenerator(X_train, Y_train, batch_size = 200, 
                                    for_train=True, augm = True, shuffle=True)
  
  val_generator = DataGenerator(X_val, Y_val, batch_size = 200, 
                                    for_train=True, augm = False, shuffle=False)
  
  history = model.fit_generator(train_generator,
                                validation_data=val_generator,
                                epochs=30, verbose=1) 
  
  # model.fit(X_train,Y_train,batch_size=128, epochs=25, validation_split=0.1, verbose=2)

  # model.load_weights(checkpoint_filepath)

  scores=model.evaluate(X_test, Y_test, verbose=0)
  print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

  if y_pred is None:
    y_pred = model.predict(X_test)
  else:
    y_pred +=model.predict(X_test)

y_pred /= MODELS_COUNT
pred = numpy.argmax(y_pred, axis=1)
acc_test = accuracy_score(y_test,pred)
# print("acc_test: ()".format(acc_test))
print("Final accuracy: {}%".format(round(acc_test*100,2)))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# Model # 0
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 200/200 [==============================] - 41s 39ms/step - loss: 2.0311 - accuracy: 0.2475 - val_loss: 1.4805 - val_accuracy: 0.4520
# Epoch 2/30
# 200/200 [==============================] - 7s 37ms/step - loss: 1.5435 - accuracy: 0.4379 - val_loss: 1.2403 - val_accuracy: 0.5575
# Epoch 3/30
# 200/200 [==============================] - 8s 38ms/step - loss: 1.3668 - accuracy: 0.5090 - val_loss: 1.0892 - val_accuracy: 0.6173
# Epoch 4/30
# 200/200 [==============================] - 8s 38ms/step - loss: 1.2449 - accuracy: 0.5527 - val_loss: 0.9534 - val_accuracy: 0.6598
# Epoch 5/30
# 200/200 [==============================] - 8s 38ms/step - loss: 1.1468 - accuracy: 0.5917 - val_loss: 0.9083 - val_accuracy: 0.6751
# Epoch 6/30
# 200/200 [==============================] - 8s 38ms/step - loss: 1.0762 - accuracy: 0.6175 - val_loss: 0.7973 - val_accuracy: 0.7234
# Epoch 7/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0210 - accuracy: 0.6421 - val_loss: 0.7721 - val_accuracy: 0.7295
# Epoch 8/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9611 - accuracy: 0.6631 - val_loss: 0.7316 - val_accuracy: 0.7433
# Epoch 9/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9227 - accuracy: 0.6751 - val_loss: 0.7198 - val_accuracy: 0.7465
# Epoch 10/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9061 - accuracy: 0.6826 - val_loss: 0.7076 - val_accuracy: 0.7522
# Epoch 11/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8722 - accuracy: 0.6936 - val_loss: 0.6678 - val_accuracy: 0.7651
# Epoch 12/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8533 - accuracy: 0.7012 - val_loss: 0.6721 - val_accuracy: 0.7635
# Epoch 13/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8215 - accuracy: 0.7094 - val_loss: 0.6395 - val_accuracy: 0.7770
# Epoch 14/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8111 - accuracy: 0.7194 - val_loss: 0.6346 - val_accuracy: 0.7754
# Epoch 15/30
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7885 - accuracy: 0.7271 - val_loss: 0.6184 - val_accuracy: 0.7845
# Epoch 16/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7751 - accuracy: 0.7281 - val_loss: 0.5988 - val_accuracy: 0.7882
# Epoch 17/30
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7579 - accuracy: 0.7391 - val_loss: 0.5965 - val_accuracy: 0.7956
# Epoch 18/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7685 - accuracy: 0.7349 - val_loss: 0.6310 - val_accuracy: 0.7813
# Epoch 19/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7376 - accuracy: 0.7428 - val_loss: 0.5680 - val_accuracy: 0.8041
# Epoch 20/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7263 - accuracy: 0.7497 - val_loss: 0.6041 - val_accuracy: 0.7908
# Epoch 21/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7299 - accuracy: 0.7440 - val_loss: 0.5720 - val_accuracy: 0.7982
# Epoch 22/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7076 - accuracy: 0.7513 - val_loss: 0.5522 - val_accuracy: 0.8125
# Epoch 23/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6869 - accuracy: 0.7617 - val_loss: 0.5876 - val_accuracy: 0.7972
# Epoch 24/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6935 - accuracy: 0.7594 - val_loss: 0.5491 - val_accuracy: 0.8133
# Epoch 25/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6723 - accuracy: 0.7668 - val_loss: 0.5539 - val_accuracy: 0.8089
# Epoch 26/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6822 - accuracy: 0.7627 - val_loss: 0.5488 - val_accuracy: 0.8050
# Epoch 27/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6674 - accuracy: 0.7696 - val_loss: 0.5195 - val_accuracy: 0.8217
# Epoch 28/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6459 - accuracy: 0.7778 - val_loss: 0.5494 - val_accuracy: 0.8112
# Epoch 29/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6417 - accuracy: 0.7733 - val_loss: 0.5417 - val_accuracy: 0.8151
# Epoch 30/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6401 - accuracy: 0.7761 - val_loss: 0.5316 - val_accuracy: 0.8194
# Точность работы на тестовых данных: 81.52%
# Model # 1
# Epoch 1/30
# 200/200 [==============================] - 9s 40ms/step - loss: 1.9669 - accuracy: 0.2706 - val_loss: 1.3658 - val_accuracy: 0.5073
# Epoch 2/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.4693 - accuracy: 0.4652 - val_loss: 1.1731 - val_accuracy: 0.5773
# Epoch 3/30
# 200/200 [==============================] - 8s 40ms/step - loss: 1.2952 - accuracy: 0.5350 - val_loss: 0.9809 - val_accuracy: 0.6493
# Epoch 4/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.1579 - accuracy: 0.5904 - val_loss: 0.9511 - val_accuracy: 0.6605
# Epoch 5/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0655 - accuracy: 0.6213 - val_loss: 0.7969 - val_accuracy: 0.7171
# Epoch 6/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0013 - accuracy: 0.6506 - val_loss: 0.7730 - val_accuracy: 0.7332
# Epoch 7/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9509 - accuracy: 0.6689 - val_loss: 0.7332 - val_accuracy: 0.7384
# Epoch 8/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9054 - accuracy: 0.6825 - val_loss: 0.7336 - val_accuracy: 0.7484
# Epoch 9/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8824 - accuracy: 0.6911 - val_loss: 0.6823 - val_accuracy: 0.7627
# Epoch 10/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8472 - accuracy: 0.7060 - val_loss: 0.6614 - val_accuracy: 0.7768
# Epoch 11/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8316 - accuracy: 0.7095 - val_loss: 0.6541 - val_accuracy: 0.7706
# Epoch 12/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8091 - accuracy: 0.7167 - val_loss: 0.6378 - val_accuracy: 0.7803
# Epoch 13/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7794 - accuracy: 0.7301 - val_loss: 0.6027 - val_accuracy: 0.7944
# Epoch 14/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7669 - accuracy: 0.7313 - val_loss: 0.5889 - val_accuracy: 0.7992
# Epoch 15/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7529 - accuracy: 0.7350 - val_loss: 0.6103 - val_accuracy: 0.7918
# Epoch 16/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7428 - accuracy: 0.7415 - val_loss: 0.5827 - val_accuracy: 0.7972
# Epoch 17/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7143 - accuracy: 0.7519 - val_loss: 0.5540 - val_accuracy: 0.8134
# Epoch 18/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6964 - accuracy: 0.7580 - val_loss: 0.5959 - val_accuracy: 0.7988
# Epoch 19/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7077 - accuracy: 0.7552 - val_loss: 0.5701 - val_accuracy: 0.8074
# Epoch 20/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6918 - accuracy: 0.7588 - val_loss: 0.5431 - val_accuracy: 0.8160
# Epoch 21/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6664 - accuracy: 0.7658 - val_loss: 0.5417 - val_accuracy: 0.8163
# Epoch 22/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6655 - accuracy: 0.7716 - val_loss: 0.5558 - val_accuracy: 0.8140
# Epoch 23/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6536 - accuracy: 0.7739 - val_loss: 0.5353 - val_accuracy: 0.8189
# Epoch 24/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6504 - accuracy: 0.7747 - val_loss: 0.5264 - val_accuracy: 0.8228
# Epoch 25/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6422 - accuracy: 0.7797 - val_loss: 0.5183 - val_accuracy: 0.8262
# Epoch 26/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6311 - accuracy: 0.7843 - val_loss: 0.5259 - val_accuracy: 0.8225
# Epoch 27/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6335 - accuracy: 0.7821 - val_loss: 0.5391 - val_accuracy: 0.8162
# Epoch 28/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6168 - accuracy: 0.7891 - val_loss: 0.5271 - val_accuracy: 0.8251
# Epoch 29/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6129 - accuracy: 0.7870 - val_loss: 0.5060 - val_accuracy: 0.8301
# Epoch 30/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.6082 - accuracy: 0.7905 - val_loss: 0.5350 - val_accuracy: 0.8197
# Точность работы на тестовых данных: 81.82%
# Model # 2
# Epoch 1/30
# 200/200 [==============================] - 9s 40ms/step - loss: 1.9465 - accuracy: 0.2775 - val_loss: 1.3393 - val_accuracy: 0.5119
# Epoch 2/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.4428 - accuracy: 0.4762 - val_loss: 1.1168 - val_accuracy: 0.5988
# Epoch 3/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.2688 - accuracy: 0.5487 - val_loss: 1.0088 - val_accuracy: 0.6472
# Epoch 4/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.1662 - accuracy: 0.5867 - val_loss: 0.8885 - val_accuracy: 0.6878
# Epoch 5/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0736 - accuracy: 0.6218 - val_loss: 0.8286 - val_accuracy: 0.7102
# Epoch 6/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0207 - accuracy: 0.6382 - val_loss: 0.7872 - val_accuracy: 0.7273
# Epoch 7/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9521 - accuracy: 0.6677 - val_loss: 0.7835 - val_accuracy: 0.7300
# Epoch 8/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9290 - accuracy: 0.6738 - val_loss: 0.7005 - val_accuracy: 0.7552
# Epoch 9/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9076 - accuracy: 0.6796 - val_loss: 0.6852 - val_accuracy: 0.7643
# Epoch 10/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8656 - accuracy: 0.6975 - val_loss: 0.6671 - val_accuracy: 0.7680
# Epoch 11/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8537 - accuracy: 0.7044 - val_loss: 0.6472 - val_accuracy: 0.7776
# Epoch 12/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8181 - accuracy: 0.7144 - val_loss: 0.6183 - val_accuracy: 0.7843
# Epoch 13/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8058 - accuracy: 0.7188 - val_loss: 0.6208 - val_accuracy: 0.7823
# Epoch 14/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7713 - accuracy: 0.7319 - val_loss: 0.6122 - val_accuracy: 0.7912
# Epoch 15/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7773 - accuracy: 0.7273 - val_loss: 0.6207 - val_accuracy: 0.7872
# Epoch 16/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7462 - accuracy: 0.7401 - val_loss: 0.6066 - val_accuracy: 0.7912
# Epoch 17/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7254 - accuracy: 0.7502 - val_loss: 0.5830 - val_accuracy: 0.7970
# Epoch 18/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7069 - accuracy: 0.7566 - val_loss: 0.5697 - val_accuracy: 0.8014
# Epoch 19/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.7145 - accuracy: 0.7508 - val_loss: 0.5717 - val_accuracy: 0.8047
# Epoch 20/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7121 - accuracy: 0.7533 - val_loss: 0.5510 - val_accuracy: 0.8134
# Epoch 21/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6925 - accuracy: 0.7608 - val_loss: 0.5672 - val_accuracy: 0.8080
# Epoch 22/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6905 - accuracy: 0.7634 - val_loss: 0.5787 - val_accuracy: 0.8016
# Epoch 23/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6700 - accuracy: 0.7668 - val_loss: 0.5603 - val_accuracy: 0.8121
# Epoch 24/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6731 - accuracy: 0.7683 - val_loss: 0.5836 - val_accuracy: 0.8037
# Epoch 25/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6583 - accuracy: 0.7719 - val_loss: 0.5536 - val_accuracy: 0.8148
# Epoch 26/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6461 - accuracy: 0.7760 - val_loss: 0.5259 - val_accuracy: 0.8273
# Epoch 27/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6441 - accuracy: 0.7801 - val_loss: 0.5742 - val_accuracy: 0.8037
# Epoch 28/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6394 - accuracy: 0.7757 - val_loss: 0.5509 - val_accuracy: 0.8154
# Epoch 29/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6089 - accuracy: 0.7850 - val_loss: 0.5028 - val_accuracy: 0.8317
# Epoch 30/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6201 - accuracy: 0.7842 - val_loss: 0.5369 - val_accuracy: 0.8257
# Точность работы на тестовых данных: 82.44%
# Model # 3
# Epoch 1/30
# 200/200 [==============================] - 8s 40ms/step - loss: 1.9609 - accuracy: 0.2746 - val_loss: 1.3773 - val_accuracy: 0.5083
# Epoch 2/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.4780 - accuracy: 0.4627 - val_loss: 1.1712 - val_accuracy: 0.5917
# Epoch 3/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.3041 - accuracy: 0.5360 - val_loss: 1.0604 - val_accuracy: 0.6275
# Epoch 4/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.1977 - accuracy: 0.5765 - val_loss: 0.9572 - val_accuracy: 0.6556
# Epoch 5/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.1155 - accuracy: 0.6080 - val_loss: 0.8565 - val_accuracy: 0.6978
# Epoch 6/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0623 - accuracy: 0.6268 - val_loss: 0.8374 - val_accuracy: 0.7052
# Epoch 7/30
# 200/200 [==============================] - 8s 40ms/step - loss: 1.0040 - accuracy: 0.6463 - val_loss: 0.7678 - val_accuracy: 0.7277
# Epoch 8/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.9571 - accuracy: 0.6653 - val_loss: 0.7602 - val_accuracy: 0.7353
# Epoch 9/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9259 - accuracy: 0.6760 - val_loss: 0.7337 - val_accuracy: 0.7436
# Epoch 10/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8903 - accuracy: 0.6871 - val_loss: 0.7691 - val_accuracy: 0.7360
# Epoch 11/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8654 - accuracy: 0.6966 - val_loss: 0.6873 - val_accuracy: 0.7581
# Epoch 12/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8647 - accuracy: 0.6987 - val_loss: 0.6493 - val_accuracy: 0.7737
# Epoch 13/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8305 - accuracy: 0.7110 - val_loss: 0.6694 - val_accuracy: 0.7710
# Epoch 14/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8052 - accuracy: 0.7212 - val_loss: 0.6432 - val_accuracy: 0.7791
# Epoch 15/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7905 - accuracy: 0.7253 - val_loss: 0.6109 - val_accuracy: 0.7882
# Epoch 16/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7752 - accuracy: 0.7311 - val_loss: 0.5985 - val_accuracy: 0.7971
# Epoch 17/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7610 - accuracy: 0.7335 - val_loss: 0.5949 - val_accuracy: 0.7961
# Epoch 18/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7474 - accuracy: 0.7383 - val_loss: 0.5819 - val_accuracy: 0.7997
# Epoch 19/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7407 - accuracy: 0.7410 - val_loss: 0.6232 - val_accuracy: 0.7946
# Epoch 20/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7192 - accuracy: 0.7500 - val_loss: 0.5812 - val_accuracy: 0.8040
# Epoch 21/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7107 - accuracy: 0.7523 - val_loss: 0.5841 - val_accuracy: 0.8075
# Epoch 22/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.7051 - accuracy: 0.7559 - val_loss: 0.5566 - val_accuracy: 0.8104
# Epoch 23/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6954 - accuracy: 0.7574 - val_loss: 0.5482 - val_accuracy: 0.8115
# Epoch 24/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6766 - accuracy: 0.7662 - val_loss: 0.5581 - val_accuracy: 0.8120
# Epoch 25/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6641 - accuracy: 0.7707 - val_loss: 0.5429 - val_accuracy: 0.8148
# Epoch 26/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6628 - accuracy: 0.7704 - val_loss: 0.5366 - val_accuracy: 0.8206
# Epoch 27/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6645 - accuracy: 0.7691 - val_loss: 0.5491 - val_accuracy: 0.8164
# Epoch 28/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6420 - accuracy: 0.7774 - val_loss: 0.5337 - val_accuracy: 0.8183
# Epoch 29/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6408 - accuracy: 0.7794 - val_loss: 0.5122 - val_accuracy: 0.8249
# Epoch 30/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6347 - accuracy: 0.7821 - val_loss: 0.5259 - val_accuracy: 0.8206
# Точность работы на тестовых данных: 81.78%
# Model # 4
# Epoch 1/30
# 200/200 [==============================] - 8s 40ms/step - loss: 2.0057 - accuracy: 0.2522 - val_loss: 1.4093 - val_accuracy: 0.5026
# Epoch 2/30
# 200/200 [==============================] - 8s 40ms/step - loss: 1.4797 - accuracy: 0.4626 - val_loss: 1.1720 - val_accuracy: 0.5747
# Epoch 3/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.3384 - accuracy: 0.5202 - val_loss: 1.1037 - val_accuracy: 0.6141
# Epoch 4/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.2092 - accuracy: 0.5702 - val_loss: 0.9308 - val_accuracy: 0.6689
# Epoch 5/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.1168 - accuracy: 0.6009 - val_loss: 0.9386 - val_accuracy: 0.6663
# Epoch 6/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0811 - accuracy: 0.6171 - val_loss: 0.8347 - val_accuracy: 0.7092
# Epoch 7/30
# 200/200 [==============================] - 8s 39ms/step - loss: 1.0226 - accuracy: 0.6366 - val_loss: 0.8034 - val_accuracy: 0.7165
# Epoch 8/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9782 - accuracy: 0.6541 - val_loss: 0.7652 - val_accuracy: 0.7366
# Epoch 9/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.9445 - accuracy: 0.6695 - val_loss: 0.7840 - val_accuracy: 0.7313
# Epoch 10/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.9339 - accuracy: 0.6712 - val_loss: 0.6893 - val_accuracy: 0.7600
# Epoch 11/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8941 - accuracy: 0.6858 - val_loss: 0.7124 - val_accuracy: 0.7530
# Epoch 12/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8664 - accuracy: 0.6985 - val_loss: 0.6784 - val_accuracy: 0.7632
# Epoch 13/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8516 - accuracy: 0.7022 - val_loss: 0.6550 - val_accuracy: 0.7736
# Epoch 14/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8167 - accuracy: 0.7124 - val_loss: 0.6380 - val_accuracy: 0.7828
# Epoch 15/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8183 - accuracy: 0.7159 - val_loss: 0.6354 - val_accuracy: 0.7815
# Epoch 16/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.8171 - accuracy: 0.7148 - val_loss: 0.6247 - val_accuracy: 0.7835
# Epoch 17/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7845 - accuracy: 0.7225 - val_loss: 0.5971 - val_accuracy: 0.7918
# Epoch 18/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7800 - accuracy: 0.7288 - val_loss: 0.6041 - val_accuracy: 0.7905
# Epoch 19/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7560 - accuracy: 0.7361 - val_loss: 0.6114 - val_accuracy: 0.7926
# Epoch 20/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7505 - accuracy: 0.7375 - val_loss: 0.6028 - val_accuracy: 0.7942
# Epoch 21/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7321 - accuracy: 0.7465 - val_loss: 0.5699 - val_accuracy: 0.8065
# Epoch 22/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.7336 - accuracy: 0.7453 - val_loss: 0.5791 - val_accuracy: 0.8057
# Epoch 23/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7189 - accuracy: 0.7542 - val_loss: 0.5704 - val_accuracy: 0.8055
# Epoch 24/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7076 - accuracy: 0.7572 - val_loss: 0.5720 - val_accuracy: 0.8050
# Epoch 25/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7051 - accuracy: 0.7567 - val_loss: 0.5457 - val_accuracy: 0.8177
# Epoch 26/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6934 - accuracy: 0.7591 - val_loss: 0.5312 - val_accuracy: 0.8166
# Epoch 27/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6871 - accuracy: 0.7597 - val_loss: 0.5564 - val_accuracy: 0.8151
# Epoch 28/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6829 - accuracy: 0.7611 - val_loss: 0.5393 - val_accuracy: 0.8152
# Epoch 29/30
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6574 - accuracy: 0.7724 - val_loss: 0.5379 - val_accuracy: 0.8164
# Epoch 30/30
# 200/200 [==============================] - 8s 40ms/step - loss: 0.6533 - accuracy: 0.7714 - val_loss: 0.5093 - val_accuracy: 0.8240
# Точность работы на тестовых данных: 81.68%
# Final accuracy: 85.04%
